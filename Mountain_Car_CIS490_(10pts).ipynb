# %% [markdown]
# <a href="https://colab.research.google.com/github/RaquanPrideJr/CIS490/blob/main/Mountain_Car_CIS490_(10pts).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##(3 pts) Short questions
#
# Fill in short definitions/answers for each of the following:
#
# **observation space** -
# **action space** -
# Left, right, neutral or 0,2,1
#
# **agent** -  Something that acts
#
# For MountainCar,
# * Is the observation space continuous or discrete?
# Discrete
# * How many dimensions is it?
# 2
#
# * Is the action space continuous or discrete?
# discrete

# %% [markdown]
# ## (3pts) Open loop agent.
# In the following cell, implement your open loop agent. You must not use the observation return variable. I will run it ten times to determine the average number of iterations to reach the top. (The lowest average in the class gets a bonus point.)

# %%
# Run this cell once to allow playable videos to be created
# Make sure it says SUCCESS after running, or rerun.

# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# install some helper functions to allow playing render videos in colab
import gym
from gym.wrappers import Monitor
import glob
import io
import base64
from IPython.display import HTML
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay

display = Display(visible=0, size=(1400, 900))
display.start()

"""
Utility functions to enable video recording of gym environment 
and displaying it.
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

print('SUCCESS!')
# Out:
# SUCCESS!

# %%
# YOUR OPEN-LOOP AGENT GOES HERE (YOU SHOULD NOT USE observation FOR THE
# OPEN LOOP AGENT) 
env = wrap_env(gym.make("MountainCar-v0"))
observation = env.reset()
print(observation)

  
# observation is a two dimensional tuple that contains the position and 
# speed. The initial position and speed is not (0,0) but rather there is
# a small random starting position and speed.
action = 2
step_i = 0  # use this variable as a counter for each step taken

while True:    
    env.render()
    
    #--------------------------------------------
    # your agent goes here (change the code here)
    # currently the action is randomly sampled from the action space
    
    #-------------------------------------------

    # The following line calls the environment simulator with the
    # specified action. It runs the physics simulator for one time
    # step, and returns the observation, reward, done, and info. 
    # For our purposes, we are only interested in observation and done.
    # done is a bool, that is true if the car reaches the flag and is
    # false otherwise. 
   
    observation, reward, done, info = env.step(action)
    if step_i ==25:
      action=0
    if step_i ==50:
    
      action=2
    print(observation)
    print(step_i)
    step_i = step_i + 1
 
    # if car reaches the flag, exit the loop
    if done: 
      break;

print('------------------------\nDONE')
print('# steps taken: ', step_i)
env.close()
show_video()
# Out:
# [-0.43647318  0.        ]
# [-4.36119208e-01  3.53972954e-04]
# 0
# [-0.43541383  0.00070538]
# 1
# [-0.43436214  0.00105168]
# 2
# [-0.43297177  0.00139037]
# 3
# [-0.43125276  0.00171901]
# 4
# [-0.42921751  0.00203524]
# 5
# [-0.42688071  0.00233681]
# 6
# [-0.42425915  0.00262156]
# 7
# [-0.42137166  0.00288749]
# 8
# [-0.41823892  0.00313275]
# 9
# [-0.41488328  0.00335564]
# 10
# [-0.41132862  0.00355465]
# 11
# [-0.40760017  0.00372846]
# 12
# [-0.40372425  0.00387592]
# 13
# [-0.39972813  0.00399612]
# 14
# [-0.39563981  0.00408832]
# 15
# [-0.39148779  0.00415203]
# 16
# [-0.38730086  0.00418693]
# 17
# [-0.38310791  0.00419294]
# 18
# [-0.37893773  0.00417018]
# 19
# [-0.37481877  0.00411896]
# 20
# [-0.37077897  0.00403979]
# 21
# [-0.3668456   0.00393338]
# 22
# [-0.36304501  0.00380058]
# 23
# [-0.35940256  0.00364245]
# 24
# [-0.35594238  0.00346018]
# 25
# [-0.35468727  0.00125511]
# 26
# [-0.35564547 -0.0009582 ]
# 27
# [-0.3588107  -0.00316523]
# 28
# [-0.36416211 -0.00535141]
# 29
# [-0.37166421 -0.00750211]
# 30
# [-0.38126678 -0.00960257]
# 31
# [-0.39290469 -0.01163791]
# 32
# [-0.40649788 -0.0135932 ]
# 33
# [-0.42195138 -0.0154535 ]
# 34
# [-0.43915548 -0.01720409]
# 35
# [-0.45798614 -0.01883067]
# 36
# [-0.47830573 -0.02031959]
# 37
# [-0.49996397 -0.02165824]
# 38
# [-0.52279933 -0.02283535]
# 39
# [-0.54664068 -0.02384135]
# 40
# [-0.57130935 -0.02466867]
# 41
# [-0.59662142 -0.02531207]
# 42
# [-0.62239018 -0.02576877]
# 43
# [-0.64842881 -0.02603863]
# 44
# [-0.67455295 -0.02612413]
# 45
# [-0.70058323 -0.02603028]
# 46
# [-0.72634762 -0.02576439]
# 47
# [-0.75168344 -0.02533582]
# 48
# [-0.77643902 -0.02475558]
# 49
# [-0.80047498 -0.02403596]
# 50
# [-0.82166505 -0.02119007]
# 51
# [-0.83990585 -0.0182408 ]
# 52
# [-0.85511468 -0.01520883]
# 53
# [-0.86722724 -0.01211255]
# 54
# [-0.8761954  -0.00896817]
# 55
# [-0.88198538 -0.00578998]
# 56
# [-0.8845762  -0.00259082]
# 57
# [-8.83958679e-01  6.17522629e-04]
# 58
# [-0.88013499  0.00382369]
# 59
# [-0.87311877  0.00701622]
# 60
# [-0.86293579  0.01018298]
# 61
# [-0.84962514  0.01331065]
# 62
# [-0.83324093  0.01638421]
# 63
# [-0.81385427  0.01938666]
# 64
# [-0.79155556  0.02229871]
# 65
# [-0.76645673  0.02509883]
# 66
# [-0.73869338  0.02776335]
# 67
# [-0.70842647  0.03026691]
# 68
# [-0.6758433   0.03258317]
# 69
# [-0.64115758  0.03468572]
# 70
# [-0.60460834  0.03654924]
# 71
# [-0.56645748  0.03815085]
# 72
# [-0.52698608  0.03947141]
# 73
# [-0.48648926  0.04049681]
# 74
# [-0.4452702   0.04121907]
# 75
# [-0.40363321  0.04163699]
# 76
# [-0.36187666  0.04175655]
# 77
# [-0.320286    0.04159066]
# 78
# [-0.27912738  0.04115862]
# 79
# [-0.23864229  0.04048509]
# 80
# [-0.19904341  0.03959888]
# 81
# [-0.16051191  0.0385315 ]
# 82
# [-0.12319612  0.03731579]
# 83
# [-0.08721153  0.0359846 ]
# 84
# [-0.05264185  0.03456968]
# 85
# [-0.01954107  0.03310079]
# 86
# [0.01206401 0.03160508]
# 87
# [0.04217073 0.03010672]
# 88
# [0.07079743 0.0286267 ]
# 89
# [0.0979803  0.02718287]
# 90
# [0.1237704 0.0257901]
# 91
# [0.14823087 0.02446047]
# 92
# [0.17143449 0.02320361]
# 93
# [0.19346151 0.02202702]
# 94
# [0.2143979  0.02093639]
# 95
# [0.23433383 0.01993593]
# 96
# [0.2533625  0.01902867]
# 97
# [0.27157923 0.01821673]
# 98
# [0.28908082 0.01750158]
# 99
# [0.30596507 0.01688425]
# 100
# [0.32233059 0.01636552]
# 101
# [0.33827666 0.01594607]
# 102
# [0.35390332 0.01562666]
# 103
# [0.36931154 0.01540821]
# 104
# [0.38460347 0.01529194]
# 105
# [0.39988289 0.01527942]
# 106
# [0.4152556  0.01537271]
# 107
# [0.43082997 0.01557437]
# 108
# [0.44671751 0.01588755]
# 109
# [0.46303355 0.01631604]
# 110
# [0.47989784 0.01686429]
# 111
# [0.49743532 0.01753747]
# 112
# [0.51577676 0.01834145]
# 113
# ------------------------
# DONE
# # steps taken:  114
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ## (4pts) Closed-loop agent.
# In the following cell, implement your closed-loop agent. You must make use of the observation variable in a meaningful way. I will run it ten times to determine the average number of iterations to reach the top. (The lowest average in the class gets a bonus point.)

# %%
# CLOSED LOOP AGENT (use observation)
# Insert code for your closed loop agent here (i.e. you should use 
# observation for deciding your next action).
# To start out, copy and paste the entire code contents of the above cell here.
# YOUR OPEN-LOOP AGENT GOES HERE (YOU SHOULD NOT USE observation FOR THE
# OPEN LOOP AGENT) 
env = wrap_env(gym.make("MountainCar-v0"))
observation = env.reset()
print(observation)

  
# observation is a two dimensional tuple that contains the position and 
# speed. The initial position and speed is not (0,0) but rather there is
# a small random starting position and speed.
action = 2
step_i = 0  # use this variable as a counter for each step taken

while True:    
    env.render()
    
    #--------------------------------------------
    # your agent goes here (change the code here)
    # currently the action is randomly sampled from the action space
    
    #-------------------------------------------

    # The following line calls the environment simulator with the
    # specified action. It runs the physics simulator for one time
    # step, and returns the observation, reward, done, and info. 
    # For our purposes, we are only interested in observation and done.
    # done is a bool, that is true if the car reaches the flag and is
    # false otherwise. 
   
    observation, reward, done, info = env.step(action)
    velocity = observation [1]
    if velocity <0: 
     action = 0
    else:
     action = 2
  
   
    
    print(observation)
    print(step_i)
    step_i = step_i + 1
 
    # if car reaches the flag, exit the loop
    if done: 
      break;

print('------------------------\nDONE')
print('# steps taken: ', step_i)
env.close()
show_video()
# Out:
# [-0.52317548  0.        ]
# [-0.52217866  0.00099683]
# 0
# [-0.52019248  0.00198617]
# 1
# [-0.51723185  0.00296063]
# 2
# [-0.51331898  0.00391288]
# 3
# [-0.50848318  0.00483579]
# 4
# [-0.50276072  0.00572246]
# 5
# [-0.49619444  0.00656628]
# 6
# [-0.48883346  0.00736098]
# 7
# [-0.48073275  0.00810071]
# 8
# [-0.47195264  0.0087801 ]
# 9
# [-0.46255834  0.0093943 ]
# 10
# [-0.45261928  0.00993906]
# 11
# [-0.44220856  0.01041072]
# 12
# [-0.43140222  0.01080634]
# 13
# [-0.42027857  0.01112365]
# 14
# [-0.40891747  0.0113611 ]
# 15
# [-0.39739961  0.01151786]
# 16
# [-0.38580579  0.01159381]
# 17
# [-0.37421625  0.01158955]
# 18
# [-0.36270994  0.01150631]
# 19
# [-0.35136399  0.01134595]
# 20
# [-0.34025308  0.01111091]
# 21
# [-0.32944897  0.01080411]
# 22
# [-0.31902004  0.01042893]
# 23
# [-0.30903093  0.00998912]
# 24
# [-0.29954221  0.00948871]
# 25
# [-0.29061021  0.008932  ]
# 26
# [-0.28228678  0.00832343]
# 27
# [-0.27461919  0.00766759]
# 28
# [-0.2676501  0.0069691]
# 29
# [-0.26141747  0.00623263]
# 30
# [-0.25595463  0.00546284]
# 31
# [-0.25129028  0.00466435]
# 32
# [-0.24744854  0.00384174]
# 33
# [-0.24444902  0.00299952]
# 34
# [-0.24230684  0.00214218]
# 35
# [-0.24103273  0.00127412]
# 36
# [-0.24063301  0.00039972]
# 37
# [-0.24110967 -0.00047666]
# 38
# [-0.24446035 -0.00335068]
# 39
# [-0.25066831 -0.00620797]
# 40
# [-0.25970208 -0.00903377]
# 41
# [-0.2715147  -0.01181262]
# 42
# [-0.28604283 -0.01452812]
# 43
# [-0.30320559 -0.01716276]
# 44
# [-0.32290347 -0.01969788]
# 45
# [-0.34501725 -0.02211379]
# 46
# [-0.36940724 -0.02438999]
# 47
# [-0.39591287 -0.02650562]
# 48
# [-0.42435289 -0.02844002]
# 49
# [-0.45452631 -0.03017342]
# 50
# [-0.48621407 -0.03168776]
# 51
# [-0.51918162 -0.03296756]
# 52
# [-0.55318231 -0.03400069]
# 53
# [-0.58796141 -0.0347791 ]
# 54
# [-0.62326079 -0.03529937]
# 55
# [-0.65882378 -0.035563  ]
# 56
# [-0.69440018 -0.0355764 ]
# 57
# [-0.72975089 -0.03535071]
# 58
# [-0.76465216 -0.03490127]
# 59
# [-0.79889904 -0.03424687]
# 60
# [-0.83230801 -0.03340898]
# 61
# [-0.86471874 -0.03241073]
# 62
# [-0.89599482 -0.03127608]
# 63
# [-0.92602372 -0.0300289 ]
# 64
# [-0.95471599 -0.02869227]
# 65
# [-0.98200386 -0.02728787]
# 66
# [-1.0078394  -0.02583554]
# 67
# [-1.03219235 -0.02435294]
# 68
# [-1.05504782 -0.02285548]
# 69
# [-1.07640399 -0.02135617]
# 70
# [-1.09626975 -0.01986576]
# 71
# [-1.11466255 -0.0183928 ]
# 72
# [-1.13160639 -0.01694383]
# 73
# [-1.14712995 -0.01552356]
# 74
# [-1.16126501 -0.01413507]
# 75
# [-1.17404504 -0.01278002]
# 76
# [-1.1855039  -0.01145887]
# 77
# [-1.1956749  -0.01017099]
# 78
# [-1.2  0. ]
# 79
# [-1.1967581  0.0032419]
# 80
# [-1.19026366  0.00649445]
# 81
# [-1.18049596  0.00976769]
# 82
# [-1.16742551  0.01307045]
# 83
# [-1.15101593  0.01640959]
# 84
# [-1.13122662  0.01978931]
# 85
# [-1.10801632  0.02321029]
# 86
# [-1.08134752  0.0266688 ]
# 87
# [-1.05119184  0.03015569]
# 88
# [-1.01753633  0.03365551]
# 89
# [-0.98039071  0.03714562]
# 90
# [-0.93979513  0.04059558]
# 91
# [-0.89582821  0.04396692]
# 92
# [-0.84861466  0.04721355]
# 93
# [-0.79833178  0.05028288]
# 94
# [-0.7452139   0.05311789]
# 95
# [-0.68955367  0.05566023]
# 96
# [-0.63169956  0.05785411]
# 97
# [-0.57204884  0.05965072]
# 98
# [-0.51103601  0.06101282]
# 99
# [-0.44911739  0.06191862]
# 100
# [-0.38675274  0.06236465]
# 101
# [-0.32438585  0.06236689]
# 102
# [-0.26242569  0.06196016]
# 103
# [-0.20122997  0.06119572]
# 104
# [-0.14109236  0.0601376 ]
# 105
# [-0.08223413  0.05885823]
# 106
# [-0.0248002   0.05743393]
# 107
# [0.03114064 0.05594084]
# 108
# [0.08559239 0.05445174]
# 109
# [0.1386261  0.05303371]
# 110
# [0.1903729  0.05174681]
# 111
# [0.24101647 0.05064356]
# 112
# [0.29078556 0.04976909]
# 113
# [0.33994708 0.04916153]
# 114
# [0.38879986 0.04885277]
# 115
# [0.43766897 0.04886911]
# 116
# [0.48690072 0.04923175]
# 117
# [0.5368578  0.04995707]
# 118
# ------------------------
# DONE
# # steps taken:  119
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
